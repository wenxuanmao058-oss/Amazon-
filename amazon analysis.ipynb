# %%
import pandas as pd

df = pd.read_csv(r"D:\项目\amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ## 运行完整分析脚本
#
# 会在内存中完成分析，并直接显示图表，不生成 `amazon_analysis_outputs`。

# %%
# %matplotlib inline
# %run amazon_analysis.py
# Out:
# Prepared products: 1,465
# Prepared reviews:  12,154
# Done. outputs: D:\python mwx\python项目\pythonProject1\amazon_analysis_outputs
# products=1,464, reviews=12,154

# %% [markdown]
# # 亚马逊评论 + 商品运营分析报告
#
# ## 1. 数据口径
#
# - 有效商品：**1,464** 条
# - 评论长表：**12,154** 条
# - 数据站点：Amazon.in 印度站，价格为 ₹ 卢比
# - 主脚本会先调用 `data_prepare.py`，在内存中从原始 `amazon.csv` 整理出商品表和评论表
# - `rating` 是商品整体评分，不是单条评论评分
# - `rating_count` 作为商品热度/销量代理
# - 品类按 `|` 分层，取最后一段作为叶子品类
# - 情感分析为词典法的粗粒度判断，不作为绝对比例
#
# ## 2. 商品运营洞察
#
# - 供给最集中：`USBCables`，商品 233 条，竞争直接
# - 需求热度：`In-Ear`、`HDMICables`、`Smartphones`、`SmartWatches`、`Mice` 平均评论数靠前
# - 价格带：折后价中位数约 **₹799**，平均折扣约 **47.7%**
# - 口碑结构：`Mice`、`HDMICables`、`SmartTelevisions`、`USBCables`、`DryIrons` 平均评分靠前
# - 综合选品候选：`HDMICables` 在商品数、需求热度和口碑上更均衡
#
# ## 3. 评论痛点挖掘
#
# - 情感分布：正向 **6,246**，中性 **4,380**，负向 **1,528**
# - 主要痛点：`Build Quality（做工质量）`、`Charging / Battery（充电 / 电池）`、`Delivery / Service（配送 / 售后）`、`Price / Value（价格 / 性价比）`、`Sound / Display（音质 / 显示）`
# - `Build Quality` 细分：`Cable / Physical Damage（线材 / 物理损坏）`、`Material / Build（材质 / 做工）`、`After-sales / Service（售后服务）`、`Display / Screen Issue（屏幕 / 显示问题）`
# - 高频词：`good`、`product`、`quality`、`cable`、`charging`、`price`
#
# Listing 应重点强调耐用性、快充能力和易用性，同时避免在质量和充电速度上过度承诺。
#
# ## 4. 运营结论
#
# 综合看，优先进入 **`HDMICables`**，同时兼顾 `In-Ear` 的流量空间和 `Mice` 的口碑优势；主推折后价 **₹799** 附近的产品，重点优化 **Build Quality** 问题，并把用户真正认可的长板作为核心卖点前置。
